# %%
import pandas as pd
from netTCR_epitopes import EpitopeSlimNetTCR

# %%
epitopes = ['GILGFVFTL', 'NLVPMVATV', 'ELAGIGILTV']
chain='TRB'
netTCR = EpitopeSlimNetTCR(epitopes=epitopes, chain=chain, folder='../vdjdb-dump', duplicate=True, 
                             prediction_path=f'prediction_duplicates_GIL_NLV_ELA_{chain}.csv', predict=True)

# %%
netTCR.roc()
# Out:
# b'# Input: duplicate_GILGFVFTL_NLVPMVATV_ELAGIGILTV_TRB.csv\n# Output file: prediction_duplicates_GIL_NLV_ELA_TRB.csv\n# Parameter directory: parameters/\n# batch size: 20\n# Blosum matrix file: parameters/BLOSUM50\n# Loading data...\n# predicting data...\n'
# /home/alex/PycharmProjects/vdjdb-classifier-benchmark/netTCR/netTCR_epitopes.py:170: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   output = pd.read_csv(f'{self.prediction_path}', header=1, sep='\t', skipfooter=1)
