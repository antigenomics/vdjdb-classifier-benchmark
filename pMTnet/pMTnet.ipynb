# %%
from epitope_data import EpitopeDataSlim

# %%
epitopes = ['GILGFVFTL', 'NLVPMVATV', 'ELAGIGILTV']

# %%
# alpha chain
chain = 'TRA'
duplicates = EpitopeDataSlim(epitopes=epitopes, chain='TRA', 
                             folder='../vdjdb-dump', duplicate=True, 
                             prediction_path=f'prediction_duplicates_GIL_NLV_ELA_{chain}.csv', 
                             predict=True)

# %%
duplicates.roc()

# %%
# beta chain
chain = 'TRB'
duplicates = EpitopeDataSlim(epitopes=epitopes, chain=chain, folder='../vdjdb-dump', 
                             duplicate=True, prediction_path=f'prediction_duplicates_GIL_NLV_ELA_{chain}.csv', 
                             predict=False)

# %%
duplicates.roc()
