# %%
from epitope_data import EpitopeDataSlim

# %%
duplicates = EpitopeDataSlim(epitopes=['GILGFVFTL', 'NLVPMVATV'], folder='../vdjdb-dump', duplicate=True,
                                prediction_path='prediction_duplicates_GIL_NLV.csv')

# %%
duplicates.roc()

# %%
# adding

# %%
duplicates = EpitopeDataSlim(epitopes=['ELAGIGILTV', 'NLVPMVATV'], folder='../vdjdb-dump', duplicate=True,
                                prediction_path='prediction.csv', predict=True)

# %%
duplicates.roc()
# Out:
# b''
